# %%
import matplotlib.pyplot as plt

# 测试的数据集大小
sizes = [1000, 5000, 10000, 20000, 50000, 80000, 120000, 200000]

# 对应的平均执行时间（微秒）
times = [48, 212, 423, 912, 1973, 3409, 5146, 8510]

plt.plot(sizes, times, marker='o')
plt.title('Ajouts Iteratifs tableau')
plt.xlabel('Size')
plt.ylabel('Execution Time (10^-6s)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 测试的数据集大小
sizes = [1000, 5000, 10000, 20000, 50000, 80000, 120000, 200000]

# 对应的平均执行时间（微秒）
times = [26, 122, 239, 499, 1363, 2062, 3007, 5292]

plt.plot(sizes, times, marker='o')
plt.title('con table')
plt.xlabel('Size')
plt.ylabel('Execution Time (10^-6s)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 测试的数据集大小
sizes = [1000, 5000, 10000, 20000, 50000, 80000, 120000, 200000]

# 对应的平均执行时间（微秒）
times = [29424, 204250, 558299, 1814639, 9876426, 24344486, 54251656, 155714402]


plt.plot(sizes, times, marker='o')

plt.title('Ajout arbre')
plt.xlabel('Size')
plt.ylabel('Execution Time (10^-6s)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 测试的数据集大小
sizes = [1000, 5000, 10000, 20000, 50000, 80000, 120000, 200000]

# 对应的平均执行时间（微秒）
times = [2129, 49646 , 195830 , 805696 , 5178231 , 13311087, 30295312,95232637]


plt.plot(sizes, times, marker='o')

plt.title('con tableua')
plt.xlabel('Size')
plt.ylabel('Execution Time (10^-6s)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 测试的数据集大小
sizes = [1000, 5000, 10000, 20000, 50000, 80000, 120000, 200000]

# 对应的平均执行时间（微秒）
times = [44, 201, 436, 807, 1616, 2662, 4559, 6516]


plt.plot(sizes, times, marker='o')

plt.title('Union tas tableau')
plt.xlabel('Size')
plt.ylabel('Execution Time (10^-6s)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 测试的数据集大小
sizes = [1000, 5000, 10000, 20000, 50000,80000,120000,200000]

# 对应的平均执行时间（微秒）
times = [40430, 1015403, 3964797, 21076707, 127472848,382929373,709234237,2109811263]


plt.plot(sizes, times, marker='o')

plt.title('Construction_FileBinomiale')
plt.xlabel('Size')
plt.ylabel('Execution Time (10^-6s)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 测试的数据集大小
sizes = [1000, 5000, 10000, 20000, 50000,80000,120000,200000]

# 对应的平均执行时间（微秒）
times = [225, 1067, 2207, 4279,23778 ,32126,45827,76592]


plt.plot(sizes, times, marker='o')

plt.title('Union_FileBinomiale')
plt.xlabel('Size')
plt.ylabel('Execution Time (10^-6s)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 时间数据（秒）
times_fb = 15.12074
times_tas_arbre = 2.405603
times_tas = 0.001159

# 创建柱状图
plt.figure(figsize=(8, 5))
plt.bar(['FileBinomiale', 'Tas Arbre', 'Tas'], [times_fb, times_tas_arbre, times_tas], color=['blue', 'red', 'green'])
plt.title("Performance Comparison - AjoutsIteratifs")
plt.ylabel("Time (seconds)")
plt.show()

# %%
# 时间数据（秒）
times_fb = 0.012372
times_tas_arbre = 0.001437
times_tas = 0.000003

# 创建柱状图
plt.figure(figsize=(8, 5))
plt.bar(['FileBinomiale', 'Tas Arbre', 'Tas'], [times_fb, times_tas_arbre, times_tas], color=['blue', 'red', 'green'])
plt.title("Performance Comparison - SupprMin")
plt.ylabel("Time (seconds)")
plt.show()

# %%
# 时间数据（秒）
times_fb = 15.020011
times_tas_arbre = 1.059755
times_tas = 0.000648

# 创建柱状图
plt.figure(figsize=(8, 5))
plt.bar(['FileBinomiale', 'Tas Arbre', 'Tas'], [times_fb, times_tas_arbre, times_tas], color=['blue', 'red', 'green'])
plt.title("Performance Comparison - Construction")
plt.ylabel("Time (seconds)")
plt.show()

# %%
# 时间数据（秒）
times_fb = 0.01715
times_tas_arbre = 0.424821
times_tas = 0.000439

# 创建柱状图
plt.figure(figsize=(8, 5))
plt.bar(['FileBinomiale', 'Tas Arbre', 'Tas'], [times_fb, times_tas_arbre, times_tas], color=['blue', 'red', 'green'])
plt.title("Performance Comparison - Union")
plt.ylabel("Time (seconds)")
plt.show()
